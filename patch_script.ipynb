# %%
import pandas as pd

# %%
# Read in the unpatched dataset
df = pd.read_csv("feedbacks.csv")
df.head(1)
# Out:
#   language       id country user_type organization surname  \
# 0       en  2665651     BEL       ngo      Equinet     NaN
#
#                                             feedback     status company_size  \
# 0  Equinet welcomes the opportunity to provide co...  PUBLISHED        micro
#
#   first_name reference_initiative        date_feedback publication  \
# 0        NaN         COM(2021)206  2021-08-06 23:57:37   anonymous
#
#    publication_id publication_status tr_number scope governance_level
# 0        24212003             closed       NaN   NaN              NaN

# %%
# Reclassification: Other -> academia
academia = [2665640, 2665609, 2665430, 2662611]
df.loc[df["id"].isin(academia), "user_type"] = "academic_research_institution"

# %%
# Reclassification: Other -> NGO
ngo = [2665628, 2665582, 2665562, 2665551, 2665524, 2665502, 2665501, 2665296] \
    + [2663361, 2662109]  # fmt: skip
df.loc[df["id"].isin(ngo), "user_type"] = "ngo"

# %%
# Reclassification: Other -> business association
business = [2665599, 2665503, 2662473, 2662182]
df.loc[df["id"].isin(business), "user_type"] = "business_association"

# %%
# Reclassification: Other -> company
company = [2665534]
df.loc[df["id"].isin(company), "user_type"] = "company"

# %%
# Reclassification: Other -> EU citizen
citizen = [2663295]
df.loc[df["id"].isin(citizen), "user_type"] = "eu_citizen"

# Citizens represent themselves, company size entries should be a mistake
df.loc[df["user_type"] == "eu_citizen", "company_size"] = None

# %%
# Reclassification: Other -> public authority
public = [2663289, 2662219, 2661501]
df.loc[df["id"].isin(public), "user_type"] = "public_authority"

# %%
# Reclassification: Other -> standardizing body
public = [2665329, 2665289, 2661384, 2635987]
df.loc[df["id"].isin(public), "user_type"] = "standardizing_body"

# %%
# Check that no standardizing bodies have other user types
df.loc[df["organization"].str.contains("Standa|standa|Norm|norm|ETSI|CEN", regex=True).fillna(False)]
# Out:
#     language       id country             user_type  \
# 109       en  2665497     BEL  business_association
# 121       en  2665478     GBR               company
# 170       nl  2665329     NLD    standardizing_body
# 180       en  2665289     FRA    standardizing_body
# 268       es  2662182     ESP  business_association
# 278       en  2661384     FRA    standardizing_body
# 291       en  2635987     DEU    standardizing_body
#
#                                           organization     surname  \
# 109                     Small Business Standards (SBS)  EDVARDSSON
# 121                                 Standard Chartered      Webber
# 170          Netherlands Normalisation Institute (NEN)    Meuleman
# 180                                               ETSI         DOR
# 268  CENTRO ESPAÑOL DE DERECHOS REPROGRÁFICOS EGDPI...       MORAN
# 278                                               ETSI         DOR
# 291            DIN Deutsches Institut für Normung e.V.      GABLER
#
#                                               feedback     status  \
# 109  SBS thanks the European Commission for the opp...  PUBLISHED
# 121  Please see attached feedback from Standard Cha...  PUBLISHED
# 170  The Medical Device / AI Expert Group (MD-AIG) ...  PUBLISHED
# 180  ETSI welcomes the draft Regulation on AI prese...  PUBLISHED
# 268  \nEstas son las contribuciones del CENTRO ESPA...  PUBLISHED
# 278  ETSI welcomes the draft Regulation on AI prese...  PUBLISHED
# 291  We welcome the European Commission's proposal ...  PUBLISHED
#
#     company_size first_name reference_initiative        date_feedback  \
# 109        micro      Maria         COM(2021)206  2021-08-06 09:46:39
# 121        large   Marianne         COM(2021)206  2021-08-05 20:41:56
# 170        large    Lysette         COM(2021)206  2021-08-04 13:51:28
# 180       medium     margot         COM(2021)206  2021-08-04 09:29:49
# 268        small   MERCEDES         COM(2021)206  2021-07-13 11:57:51
# 278       medium     margot         COM(2021)206  2021-07-06 18:10:48
# 291        large    Sibylle         COM(2021)206  2021-06-15 15:50:26
#
#     publication  publication_id publication_status          tr_number scope  \
# 109    withinfo        24212003             closed    653009713663-08   NaN
# 121    withinfo        24212003             closed     16595501800-80   NaN
# 170    withinfo        24212003             closed                NaN   NaN
# 180    withinfo        24212003             closed  474710916419-15     NaN
# 268    withinfo        24212003             closed    021880022200-45   NaN
# 278    withinfo        24212003             closed  474710916419-15     NaN
# 291    withinfo        24212003             closed    989808524267-58   NaN
#
#     governance_level
# 109              NaN
# 121              NaN
# 170              NaN
# 180              NaN
# 268              NaN
# 278              NaN
# 291              NaN

# %%
# Fix typo in user type
df["user_type"] = df["user_type"].map(
    lambda x: x
    if x != "academic_research_instittution"
    else "academic_research_institution"
)

# %%
# Look for submissions with duplicate organization names
dup_orgs = df["organization"].value_counts()
dup_orgs = dup_orgs[dup_orgs > 1].index

# Look for submissions with duplicate author names
df["full_name"] = df["first_name"] + " " + df["surname"]
dup_names = df["full_name"].value_counts()
dup_names = dup_names[dup_names > 1].index

# Show all duplicates
pd.concat(
    (
        df.query("organization.isin(@dup_orgs)").sort_values("organization"),
        df.query("full_name.isin(@dup_names)").sort_values("full_name"),
    )
).drop_duplicates(subset="id")
# Out:
#     language       id country             user_type  \
# 105       en  2665502     BEL                   ngo
# 106       en  2665501     BEL                   ngo
# 180       en  2665289     FRA    standardizing_body
# 278       en  2661384     FRA    standardizing_body
# 49        en  2665583     DEU               company
# 64        en  2665559     DEU               company
# 36        en  2665603     DEU               company
# 37        en  2665602     DEU  business_association
# 26        en  2665616     FRA           trade_union
# 79        en  2665537     FRA           trade_union
# 50        en  2665582     GBR                   ngo
# 67        en  2665554     IRL               company
# 257       en  2662603     DEU            eu_citizen
# 258       de  2662602     DEU            eu_citizen
#
#                                           organization    surname  \
# 105                                         AI4Belgium   Ackerman
# 106                                         AI4Belgium        NaN
# 180                                               ETSI        DOR
# 278                                               ETSI        DOR
# 49                            Infineon Technologies AG  SEBASTIAN
# 64                            Infineon Technologies AG        NaN
# 36                                   European AI Forum   Dickmann
# 37                               KI Bundesverband e.V.   Dickmann
# 26   Federation of Craft Businesses in the automoti...    CASTELL
# 79   Federation of Craft Businesses in the automoti...    CASTELL
# 50                                      SHERPA Project   Santiago
# 67                                 Trilateral Research   Santiago
# 257                                                NaN    Glauner
# 258                                                NaN    Glauner
#
#                                               feedback     status  \
# 105  Key feedback points\n1)\tOverall, the proposed...  PUBLISHED
# 106  Key feedback points\n1)\tOverall, the proposed...  PUBLISHED
# 180  ETSI welcomes the draft Regulation on AI prese...  PUBLISHED
# 278  ETSI welcomes the draft Regulation on AI prese...  PUBLISHED
# 49   Overall, Infineon Technologies AG welcomes the...  PUBLISHED
# 64   Overall, Infineon Technologies AG welcomes the...  PUBLISHED
# 36   Please find attached joint response to the Eur...  PUBLISHED
# 37   Please find attached KI Bundesverband's respon...  PUBLISHED
# 26   Federation of Craft Businesses in the automoti...  PUBLISHED
# 79   Federation of Craft Businesses in the automoti...  PUBLISHED
# 50   SHERPA (Shaping the ethical dimensions of smar...  PUBLISHED
# 67   Trilateral Research is a UK and IE-based ethic...  PUBLISHED
# 257  An Assessment of the AI Regulation Proposed by...  PUBLISHED
# 258  Schriftliche Stellungnahme von Prof. Dr. Patri...  PUBLISHED
#
#     company_size first_name reference_initiative        date_feedback  \
# 105        large  Nathanael         COM(2021)206  2021-08-06 09:55:40
# 106        large        NaN         COM(2021)206  2021-08-06 09:54:36
# 180       medium     margot         COM(2021)206  2021-08-04 09:29:49
# 278       medium     margot         COM(2021)206  2021-07-06 18:10:48
# 49         large        Ina         COM(2021)206  2021-08-06 16:27:53
# 64         large        NaN         COM(2021)206  2021-08-06 14:42:26
# 36         large       Alex         COM(2021)206  2021-08-06 17:52:24
# 37         large       Alex         COM(2021)206  2021-08-06 17:48:40
# 26         small   Brigitte         COM(2021)206  2021-08-06 19:26:07
# 79         small   Brigitte         COM(2021)206  2021-08-06 13:19:08
# 50         small     Nicole         COM(2021)206  2021-08-06 16:22:31
# 67        medium     Nicole         COM(2021)206  2021-08-06 14:16:25
# 257         None    Patrick         COM(2021)206  2021-07-19 10:50:45
# 258         None    Patrick         COM(2021)206  2021-07-19 10:28:20
#
#     publication  publication_id publication_status          tr_number scope  \
# 105    withinfo        24212003             closed                NaN   NaN
# 106   anonymous        24212003             closed                NaN   NaN
# 180    withinfo        24212003             closed  474710916419-15     NaN
# 278    withinfo        24212003             closed  474710916419-15     NaN
# 49     withinfo        24212003             closed     10751968675-85   NaN
# 64    anonymous        24212003             closed     10751968675-85   NaN
# 36     withinfo        24212003             closed                NaN   NaN
# 37     withinfo        24212003             closed                NaN   NaN
# 26     withinfo        24212003             closed    705440625408-01   NaN
# 79     withinfo        24212003             closed    705440625408-01   NaN
# 50     withinfo        24212003             closed                NaN   NaN
# 67     withinfo        24212003             closed    841780842634-63   NaN
# 257    withinfo        24212003             closed                NaN   NaN
# 258    withinfo        24212003             closed                NaN   NaN
#
#     governance_level           full_name
# 105              NaN  Nathanael Ackerman
# 106              NaN                 NaN
# 180              NaN          margot DOR
# 278              NaN          margot DOR
# 49               NaN       Ina SEBASTIAN
# 64               NaN                 NaN
# 36               NaN       Alex Dickmann
# 37               NaN       Alex Dickmann
# 26               NaN    Brigitte CASTELL
# 79               NaN    Brigitte CASTELL
# 50               NaN     Nicole Santiago
# 67               NaN     Nicole Santiago
# 257              NaN     Patrick Glauner
# 258              NaN     Patrick Glauner

# %%
# Remove duplicate submissions
duplicates = [2665559, 2661384, 2665501, 2665537]
df = df.query("~id.isin(@duplicates)")

# %%
# Simple statistic
df["user_type"].value_counts()
# Out:
# company                          87
# business_association             79
# ngo                              64
# academic_research_institution    24
# trade_union                      14
# eu_citizen                       13
# public_authority                 11
# consumer_organisation             5
# standardizing_body                3
# Name: user_type, dtype: int64

# %%
# Limit to actually published feedback (in case some got rejected)
df = df.query("status == 'PUBLISHED'")

# %%
df.to_csv("patched_feedbacks.csv", index=False)
